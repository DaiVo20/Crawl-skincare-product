# %%
from wordcloud import WordCloud
from matplotlib import rcParams
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
df = pd.read_csv("pre_data.csv")

# %%
cmt_df = df.comments

# %%
cmt_txt = ' '.join(cmt_df)

# %%
stop_words = set(pd.read_csv('vietnamese-stopwords.txt'))

# %%
word_tokens = word_tokenize(cmt_txt)
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

# %%
rcParams['figure.figsize']=15,8
wordcloud =WordCloud(max_words=200, max_font_size=40, scale=3).generate(' '.join(filtered_sentence))

# %%
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
